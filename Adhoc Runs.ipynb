# %%
env = dbutils.notebook.run("/Workspace/anihan_tech_np/anihan_tech_np/00_Parameters/env_dependencies", 120)
print(env)

# %%
spark.sql(f"""
          SELECT * FROM anihan_tech_{env}.00_master_01_brz.masterdata_company
          """).display()

# %%
# spark.sql(f"""
#           delete from anihan_tech_{env}.00_master_01_brz.masterdata_company
#           where company_id = 'A02'
#           """)
