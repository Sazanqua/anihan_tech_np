# %%
dbutils.widgets.dropdown(
    "env",
    "np", #default value of the dropdown widget, change depending on the environment
    ["np", "p"], #np - nonprod, p - prod 
    "Environment"
)

env = dbutils.widgets.get("env")
print(env)

# %%
dbutils.notebook.exit(env)
